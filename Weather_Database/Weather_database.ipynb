# %%
# Dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import requests

# Import API keys
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nanortalik
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | pakxan
# Processing Record 5 of Set 1 | nadapuram
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 1 | beringovskiy
# Processing Record 9 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | bambous virieux
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | lata
# Processing Record 16 of Set 1 | pemangkat
# Processing Record 17 of Set 1 | hualmay
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | fortuna
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | gat
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | ishigaki
# Processing Record 27 of Set 1 | buala
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | jiazi
# Processing Record 31 of Set 1 | cairns
# Processing Record 32 of Set 1 | bulaevo
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | dickinson
# Processing Record 35 of Set 1 | kodinsk
# Processing Record 36 of Set 1 | ostrovnoy
# Processing Record 37 of Set 1 | maxixe
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | xichang
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | bouna
# Processing Record 43 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | doha
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | tuatapere
# Processing Record 49 of Set 1 | ha giang
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | nouadhibou
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | khatanga
# Processing Record 4 of Set 2 | kulhudhuffushi
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | isangel
# Processing Record 8 of Set 2 | ziro
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | rawson
# Processing Record 12 of Set 2 | aklavik
# Processing Record 13 of Set 2 | calahorra
# Processing Record 14 of Set 2 | brigantine
# Processing Record 15 of Set 2 | teahupoo
# Processing Record 16 of Set 2 | tonantins
# Processing Record 17 of Set 2 | dano
# Processing Record 18 of Set 2 | grindavik
# Processing Record 19 of Set 2 | reconquista
# Processing Record 20 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 2 | bago
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | ossora
# Processing Record 24 of Set 2 | wladyslawowo
# Processing Record 25 of Set 2 | andenes
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | nabire
# Processing Record 29 of Set 2 | eureka
# Processing Record 30 of Set 2 | shestakovo
# Processing Record 31 of Set 2 | vila franca do campo
# Processing Record 32 of Set 2 | dumas
# Processing Record 33 of Set 2 | te anau
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | sao filipe
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 2 | big spring
# Processing Record 41 of Set 2 | lorengau
# Processing Record 42 of Set 2 | san quintin
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | pathein
# Processing Record 48 of Set 2 | la ronge
# Processing Record 49 of Set 2 | wuwei
# Processing Record 50 of Set 2 | high level
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | eyl
# Processing Record 3 of Set 3 | carbonia
# Processing Record 4 of Set 3 | juneau
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | mangrol
# Processing Record 7 of Set 3 | poum
# Processing Record 8 of Set 3 | karratha
# Processing Record 9 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 10 of Set 3 | puerto escondido
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | bandarbeyla
# Processing Record 13 of Set 3 | mabaruma
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | castro
# Processing Record 16 of Set 3 | nanao
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | tecpan
# Processing Record 19 of Set 3 | xining
# Processing Record 20 of Set 3 | lebu
# Processing Record 21 of Set 3 | koumac
# Processing Record 22 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 3 | albany
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | pareora
# Processing Record 28 of Set 3 | neuquen
# Processing Record 29 of Set 3 | new norfolk
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | klyuchevskiy
# Processing Record 32 of Set 3 | tezu
# Processing Record 33 of Set 3 | tigzirt
# Processing Record 34 of Set 3 | constitucion
# Processing Record 35 of Set 3 | jamestown
# Processing Record 36 of Set 3 | yangjiang
# Processing Record 37 of Set 3 | saskylakh
# Processing Record 38 of Set 3 | ahipara
# Processing Record 39 of Set 3 | yinchuan
# Processing Record 40 of Set 3 | asfi
# Processing Record 41 of Set 3 | faanui
# Processing Record 42 of Set 3 | filotion
# Processing Record 43 of Set 3 | tra vinh
# Processing Record 44 of Set 3 | paengaroa
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | kungurtug
# Processing Record 47 of Set 3 | sayyan
# Processing Record 48 of Set 3 | itoman
# Processing Record 49 of Set 3 | pisco
# Processing Record 50 of Set 3 | salalah
# Processing Record 1 of Set 4 | dhamtari
# Processing Record 2 of Set 4 | hilo
# Processing Record 3 of Set 4 | grants
# Processing Record 4 of Set 4 | havre-saint-pierre
# Processing Record 5 of Set 4 | qianan
# Processing Record 6 of Set 4 | vila velha
# Processing Record 7 of Set 4 | ust-kulom
# Processing Record 8 of Set 4 | bushehr
# Processing Record 9 of Set 4 | kodiak
# Processing Record 10 of Set 4 | alba
# Processing Record 11 of Set 4 | iqaluit
# Processing Record 12 of Set 4 | faya
# Processing Record 13 of Set 4 | olean
# Processing Record 14 of Set 4 | pokhara
# Processing Record 15 of Set 4 | wanning
# Processing Record 16 of Set 4 | houston
# Processing Record 17 of Set 4 | marovoay
# Processing Record 18 of Set 4 | yingshang
# City not found. Skipping...
# Processing Record 19 of Set 4 | quiindy
# Processing Record 20 of Set 4 | omurtag
# Processing Record 21 of Set 4 | talnakh
# Processing Record 22 of Set 4 | coquimbo
# Processing Record 23 of Set 4 | kailua
# Processing Record 24 of Set 4 | sambava
# Processing Record 25 of Set 4 | eufaula
# Processing Record 26 of Set 4 | maragogi
# Processing Record 27 of Set 4 | kattivakkam
# Processing Record 28 of Set 4 | jieshi
# Processing Record 29 of Set 4 | luderitz
# Processing Record 30 of Set 4 | vanavara
# Processing Record 31 of Set 4 | nizhnevartovsk
# Processing Record 32 of Set 4 | buraydah
# Processing Record 33 of Set 4 | lunca muresului
# Processing Record 34 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 4 | antigonish
# Processing Record 36 of Set 4 | smoky lake
# Processing Record 37 of Set 4 | hay river
# Processing Record 38 of Set 4 | jingdezhen
# Processing Record 39 of Set 4 | humaita
# Processing Record 40 of Set 4 | corinth
# Processing Record 41 of Set 4 | olafsvik
# Processing Record 42 of Set 4 | basoko
# Processing Record 43 of Set 4 | airai
# Processing Record 44 of Set 4 | khash
# Processing Record 45 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 4 | russell
# Processing Record 47 of Set 4 | mount forest
# Processing Record 48 of Set 4 | provideniya
# Processing Record 49 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 5 | ishinomaki
# Processing Record 2 of Set 5 | sena madureira
# Processing Record 3 of Set 5 | ginda
# Processing Record 4 of Set 5 | saint-philippe
# Processing Record 5 of Set 5 | katsuura
# Processing Record 6 of Set 5 | west bay
# Processing Record 7 of Set 5 | prainha
# Processing Record 8 of Set 5 | rocha
# Processing Record 9 of Set 5 | burica
# City not found. Skipping...
# Processing Record 10 of Set 5 | asau
# Processing Record 11 of Set 5 | comodoro rivadavia
# Processing Record 12 of Set 5 | zhigansk
# Processing Record 13 of Set 5 | havelock
# Processing Record 14 of Set 5 | cap malheureux
# Processing Record 15 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 5 | griffith
# Processing Record 17 of Set 5 | chuy
# Processing Record 18 of Set 5 | sisimiut
# Processing Record 19 of Set 5 | rosa zarate
# Processing Record 20 of Set 5 | axim
# Processing Record 21 of Set 5 | devils lake
# Processing Record 22 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 23 of Set 5 | ambilobe
# Processing Record 24 of Set 5 | vostok
# Processing Record 25 of Set 5 | fairbanks
# Processing Record 26 of Set 5 | thompson
# Processing Record 27 of Set 5 | atar
# Processing Record 28 of Set 5 | padang
# Processing Record 29 of Set 5 | alexandria
# Processing Record 30 of Set 5 | ipeti
# City not found. Skipping...
# Processing Record 31 of Set 5 | mogadishu
# Processing Record 32 of Set 5 | namibe
# Processing Record 33 of Set 5 | sakete
# Processing Record 34 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 5 | port hardy
# Processing Record 36 of Set 5 | lugo
# Processing Record 37 of Set 5 | monrovia
# Processing Record 38 of Set 5 | tahe
# Processing Record 39 of Set 5 | iracoubo
# Processing Record 40 of Set 5 | ixmiquilpan
# Processing Record 41 of Set 5 | araouane
# Processing Record 42 of Set 5 | dauphin
# Processing Record 43 of Set 5 | graciano sanchez
# Processing Record 44 of Set 5 | jiayuguan
# Processing Record 45 of Set 5 | klaksvik
# Processing Record 46 of Set 5 | castanos
# Processing Record 47 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 5 | cabo san lucas
# Processing Record 49 of Set 5 | magadan
# Processing Record 50 of Set 5 | najran
# Processing Record 1 of Set 6 | liverpool
# Processing Record 2 of Set 6 | port elizabeth
# Processing Record 3 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 6 | teneguiban
# City not found. Skipping...
# Processing Record 5 of Set 6 | waipawa
# Processing Record 6 of Set 6 | inirida
# Processing Record 7 of Set 6 | broken hill
# Processing Record 8 of Set 6 | komsomolskiy
# Processing Record 9 of Set 6 | acari
# Processing Record 10 of Set 6 | khorinsk
# Processing Record 11 of Set 6 | codrington
# Processing Record 12 of Set 6 | northam
# Processing Record 13 of Set 6 | bereda
# Processing Record 14 of Set 6 | kutno
# Processing Record 15 of Set 6 | ornskoldsvik
# Processing Record 16 of Set 6 | gamba
# Processing Record 17 of Set 6 | sungaipenuh
# Processing Record 18 of Set 6 | belle fourche
# Processing Record 19 of Set 6 | yerbogachen
# Processing Record 20 of Set 6 | sao felix do xingu
# Processing Record 21 of Set 6 | cobh
# Processing Record 22 of Set 6 | port lincoln
# Processing Record 23 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 6 | rolla
# Processing Record 25 of Set 6 | tshikapa
# Processing Record 26 of Set 6 | rudnichnyy
# Processing Record 27 of Set 6 | akonolinga
# Processing Record 28 of Set 6 | bure
# Processing Record 29 of Set 6 | broome
# Processing Record 30 of Set 6 | matiari
# Processing Record 31 of Set 6 | aksarka
# Processing Record 32 of Set 6 | zheleznodorozhnyy
# Processing Record 33 of Set 6 | anadyr
# Processing Record 34 of Set 6 | kysyl-syr
# Processing Record 35 of Set 6 | las vegas
# Processing Record 36 of Set 6 | caravelas
# Processing Record 37 of Set 6 | nantucket
# Processing Record 38 of Set 6 | odessa
# Processing Record 39 of Set 6 | dunda
# Processing Record 40 of Set 6 | mushie
# Processing Record 41 of Set 6 | mount gambier
# Processing Record 42 of Set 6 | geelong
# Processing Record 43 of Set 6 | lodwar
# Processing Record 44 of Set 6 | zhangjiakou
# Processing Record 45 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 6 | namatanai
# Processing Record 47 of Set 6 | mirpur sakro
# Processing Record 48 of Set 6 | santa cruz
# Processing Record 49 of Set 6 | umm lajj
# Processing Record 50 of Set 6 | kibaek
# Processing Record 1 of Set 7 | moindou
# Processing Record 2 of Set 7 | tazovskiy
# Processing Record 3 of Set 7 | jobat
# Processing Record 4 of Set 7 | obo
# Processing Record 5 of Set 7 | dali
# Processing Record 6 of Set 7 | sabzevar
# Processing Record 7 of Set 7 | kurchum
# Processing Record 8 of Set 7 | erzin
# Processing Record 9 of Set 7 | sihora
# Processing Record 10 of Set 7 | pochutla
# Processing Record 11 of Set 7 | muros
# Processing Record 12 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 7 | manoel urbano
# Processing Record 14 of Set 7 | lagoa
# Processing Record 15 of Set 7 | morros
# Processing Record 16 of Set 7 | kasongo-lunda
# Processing Record 17 of Set 7 | gondanglegi
# Processing Record 18 of Set 7 | tashtyp
# Processing Record 19 of Set 7 | long branch
# Processing Record 20 of Set 7 | tautira
# Processing Record 21 of Set 7 | vieux-habitants
# Processing Record 22 of Set 7 | beatrice
# Processing Record 23 of Set 7 | alekseyevka
# Processing Record 24 of Set 7 | kupang
# Processing Record 25 of Set 7 | natal
# Processing Record 26 of Set 7 | ofaqim
# Processing Record 27 of Set 7 | talaya
# Processing Record 28 of Set 7 | saint-denis
# Processing Record 29 of Set 7 | huarmey
# Processing Record 30 of Set 7 | saint-georges
# Processing Record 31 of Set 7 | saint george
# Processing Record 32 of Set 7 | vitim
# Processing Record 33 of Set 7 | brus laguna
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | arlit
# Processing Record 36 of Set 7 | marzuq
# Processing Record 37 of Set 7 | turtkul
# City not found. Skipping...
# Processing Record 38 of Set 7 | kaele
# Processing Record 39 of Set 7 | ust-tsilma
# Processing Record 40 of Set 7 | souillac
# Processing Record 41 of Set 7 | munai
# Processing Record 42 of Set 7 | esperance
# Processing Record 43 of Set 7 | skorodnoye
# Processing Record 44 of Set 7 | ewa beach
# Processing Record 45 of Set 7 | nelson bay
# Processing Record 46 of Set 7 | omboue
# Processing Record 47 of Set 7 | colombo
# Processing Record 48 of Set 7 | okahandja
# Processing Record 49 of Set 7 | mehamn
# Processing Record 50 of Set 7 | oranjemund
# Processing Record 1 of Set 8 | khudumelapye
# Processing Record 2 of Set 8 | lavrentiya
# Processing Record 3 of Set 8 | marathon
# Processing Record 4 of Set 8 | ancud
# Processing Record 5 of Set 8 | arawa
# Processing Record 6 of Set 8 | carnarvon
# Processing Record 7 of Set 8 | raudeberg
# Processing Record 8 of Set 8 | sangar
# Processing Record 9 of Set 8 | limbang
# Processing Record 10 of Set 8 | sonkovo
# Processing Record 11 of Set 8 | alyangula
# Processing Record 12 of Set 8 | korla
# Processing Record 13 of Set 8 | flin flon
# Processing Record 14 of Set 8 | upernavik
# Processing Record 15 of Set 8 | ambon
# Processing Record 16 of Set 8 | santander
# Processing Record 17 of Set 8 | kemijarvi
# Processing Record 18 of Set 8 | arboletes
# Processing Record 19 of Set 8 | proletarskiy
# Processing Record 20 of Set 8 | santa fe
# Processing Record 21 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 22 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 8 | prince rupert
# Processing Record 25 of Set 8 | goderich
# Processing Record 26 of Set 8 | atherton
# Processing Record 27 of Set 8 | katherine
# Processing Record 28 of Set 8 | gimli
# Processing Record 29 of Set 8 | christchurch
# Processing Record 30 of Set 8 | srednekolymsk
# Processing Record 31 of Set 8 | yarmouth
# Processing Record 32 of Set 8 | castelldefels
# Processing Record 33 of Set 8 | gorontalo
# Processing Record 34 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 8 | santa rosalia
# Processing Record 36 of Set 8 | esil
# Processing Record 37 of Set 8 | san patricio
# Processing Record 38 of Set 8 | shelbyville
# Processing Record 39 of Set 8 | general roca
# Processing Record 40 of Set 8 | ponta do sol
# Processing Record 41 of Set 8 | killybegs
# Processing Record 42 of Set 8 | bratsk
# Processing Record 43 of Set 8 | makat
# Processing Record 44 of Set 8 | mwinilunga
# Processing Record 45 of Set 8 | pangoa
# Processing Record 46 of Set 8 | camacha
# Processing Record 47 of Set 8 | kaeo
# Processing Record 48 of Set 8 | la palma
# Processing Record 49 of Set 8 | sibolga
# Processing Record 50 of Set 8 | mahina
# Processing Record 1 of Set 9 | dunedin
# Processing Record 2 of Set 9 | belyy yar
# Processing Record 3 of Set 9 | van
# Processing Record 4 of Set 9 | moryakovskiy zaton
# Processing Record 5 of Set 9 | altus
# Processing Record 6 of Set 9 | bud
# Processing Record 7 of Set 9 | boyolangu
# Processing Record 8 of Set 9 | igrim
# Processing Record 9 of Set 9 | virginia beach
# Processing Record 10 of Set 9 | ust-maya
# Processing Record 11 of Set 9 | qaqortoq
# Processing Record 12 of Set 9 | lyuban
# Processing Record 13 of Set 9 | bathsheba
# Processing Record 14 of Set 9 | adrar
# Processing Record 15 of Set 9 | tuy hoa
# Processing Record 16 of Set 9 | vao
# Processing Record 17 of Set 9 | severo-kurilsk
# Processing Record 18 of Set 9 | flinders
# Processing Record 19 of Set 9 | mazagao
# Processing Record 20 of Set 9 | henties bay
# Processing Record 21 of Set 9 | guajara-mirim
# City not found. Skipping...
# Processing Record 22 of Set 9 | fort nelson
# Processing Record 23 of Set 9 | riyadh
# Processing Record 24 of Set 9 | dosso
# Processing Record 25 of Set 9 | lannion
# Processing Record 26 of Set 9 | verkhnyaya maksakovka
# Processing Record 27 of Set 9 | lerwick
# Processing Record 28 of Set 9 | knysna
# Processing Record 29 of Set 9 | iranshahr
# Processing Record 30 of Set 9 | pevek
# Processing Record 31 of Set 9 | san policarpo
# Processing Record 32 of Set 9 | bela
# Processing Record 33 of Set 9 | hami
# Processing Record 34 of Set 9 | jiangyou
# Processing Record 35 of Set 9 | zhanaozen
# Processing Record 36 of Set 9 | stromness
# Processing Record 37 of Set 9 | benito juarez
# Processing Record 38 of Set 9 | tarhunah
# City not found. Skipping...
# Processing Record 39 of Set 9 | hachinohe
# Processing Record 40 of Set 9 | egvekinot
# Processing Record 41 of Set 9 | chirongui
# Processing Record 42 of Set 9 | solnechnyy
# Processing Record 43 of Set 9 | linguere
# Processing Record 44 of Set 9 | moctezuma
# Processing Record 45 of Set 9 | aykhal
# Processing Record 46 of Set 9 | biak
# Processing Record 47 of Set 9 | narsaq
# Processing Record 48 of Set 9 | vicksburg
# Processing Record 49 of Set 9 | birao
# Processing Record 50 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 1 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 2 of Set 10 | soyo
# Processing Record 3 of Set 10 | trapani
# Processing Record 4 of Set 10 | krasnoselkup
# Processing Record 5 of Set 10 | hofn
# Processing Record 6 of Set 10 | popondetta
# Processing Record 7 of Set 10 | geraldton
# Processing Record 8 of Set 10 | bulgan
# Processing Record 9 of Set 10 | yenangyaung
# Processing Record 10 of Set 10 | vinh
# Processing Record 11 of Set 10 | dingle
# Processing Record 12 of Set 10 | kamenka
# Processing Record 13 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 10 | kutum
# Processing Record 15 of Set 10 | hamilton
# Processing Record 16 of Set 10 | felipe carrillo puerto
# Processing Record 17 of Set 10 | moose jaw
# Processing Record 18 of Set 10 | poggibonsi
# Processing Record 19 of Set 10 | hobyo
# Processing Record 20 of Set 10 | kentau
# Processing Record 21 of Set 10 | kibre mengist
# Processing Record 22 of Set 10 | finnsnes
# Processing Record 23 of Set 10 | kouroussa
# Processing Record 24 of Set 10 | tuam
# Processing Record 25 of Set 10 | santa maria
# Processing Record 26 of Set 10 | yokadouma
# Processing Record 27 of Set 10 | port moresby
# Processing Record 28 of Set 10 | grand gaube
# Processing Record 29 of Set 10 | sola
# Processing Record 30 of Set 10 | aksu
# Processing Record 31 of Set 10 | pryazha
# Processing Record 32 of Set 10 | lasa
# Processing Record 33 of Set 10 | sampit
# Processing Record 34 of Set 10 | moron
# Processing Record 35 of Set 10 | kaniama
# Processing Record 36 of Set 10 | xai-xai
# Processing Record 37 of Set 10 | olinala
# Processing Record 38 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 39 of Set 10 | saint-pierre
# Processing Record 40 of Set 10 | kampene
# Processing Record 41 of Set 10 | gawler
# Processing Record 42 of Set 10 | juegang
# Processing Record 43 of Set 10 | radom
# Processing Record 44 of Set 10 | westport
# Processing Record 45 of Set 10 | peniche
# Processing Record 46 of Set 10 | baoding
# Processing Record 47 of Set 10 | sesheke
# Processing Record 48 of Set 10 | ellenabad
# Processing Record 49 of Set 10 | pervomaysk
# Processing Record 50 of Set 10 | cabedelo
# Processing Record 1 of Set 11 | hasaki
# Processing Record 2 of Set 11 | goundam
# Processing Record 3 of Set 11 | girona
# Processing Record 4 of Set 11 | yalova
# Processing Record 5 of Set 11 | vangaindrano
# Processing Record 6 of Set 11 | thunder bay
# Processing Record 7 of Set 11 | coahuayana
# Processing Record 8 of Set 11 | forbes
# Processing Record 9 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 11 | avera
# Processing Record 11 of Set 11 | half moon bay
# Processing Record 12 of Set 11 | chernyshevskiy
# Processing Record 13 of Set 11 | saint-augustin
# Processing Record 14 of Set 11 | saint-nazaire
# Processing Record 15 of Set 11 | port macquarie
# Processing Record 16 of Set 11 | coihaique
# Processing Record 17 of Set 11 | khamgaon
# Processing Record 18 of Set 11 | kruisfontein
# Processing Record 19 of Set 11 | mantua
# Processing Record 20 of Set 11 | beloha
# Processing Record 21 of Set 11 | dori
# Processing Record 22 of Set 11 | ilam
# Processing Record 23 of Set 11 | taft
# Processing Record 24 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 11 | port-gentil
# Processing Record 26 of Set 11 | salekhard
# Processing Record 27 of Set 11 | maniitsoq
# Processing Record 28 of Set 11 | lapeer
# Processing Record 29 of Set 11 | saldanha
# Processing Record 30 of Set 11 | panguna
# Processing Record 31 of Set 11 | maceio
# Processing Record 32 of Set 11 | sakakah
# Processing Record 33 of Set 11 | mirador
# Processing Record 34 of Set 11 | athabasca
# Processing Record 35 of Set 11 | puqi
# Processing Record 36 of Set 11 | tadine
# Processing Record 37 of Set 11 | banjar
# Processing Record 38 of Set 11 | nhulunbuy
# Processing Record 39 of Set 11 | bantou
# Processing Record 40 of Set 11 | wuchi
# Processing Record 41 of Set 11 | turukhansk
# Processing Record 42 of Set 11 | grande-riviere
# City not found. Skipping...
# Processing Record 43 of Set 11 | baglung
# Processing Record 44 of Set 11 | kahului
# Processing Record 45 of Set 11 | ulverstone
# Processing Record 46 of Set 11 | camara de lobos
# Processing Record 47 of Set 11 | fort frances
# Processing Record 48 of Set 11 | haicheng
# Processing Record 49 of Set 11 | wuzhou
# Processing Record 50 of Set 11 | cabra
# Processing Record 1 of Set 12 | udachnyy
# Processing Record 2 of Set 12 | tottori
# Processing Record 3 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 12 | cape coast
# Processing Record 5 of Set 12 | figeac
# Processing Record 6 of Set 12 | paralimni
# Processing Record 7 of Set 12 | general pico
# Processing Record 8 of Set 12 | eskil
# Processing Record 9 of Set 12 | the valley
# Processing Record 10 of Set 12 | chalus
# Processing Record 11 of Set 12 | bilibino
# Processing Record 12 of Set 12 | necochea
# Processing Record 13 of Set 12 | porbandar
# Processing Record 14 of Set 12 | san vicente
# Processing Record 15 of Set 12 | nanakuli
# Processing Record 16 of Set 12 | gao
# Processing Record 17 of Set 12 | alofi
# Processing Record 18 of Set 12 | oia
# Processing Record 19 of Set 12 | yar-sale
# Processing Record 20 of Set 12 | guerrero negro
# Processing Record 21 of Set 12 | daru
# Processing Record 22 of Set 12 | sainte-suzanne
# Processing Record 23 of Set 12 | fredericksburg
# Processing Record 24 of Set 12 | machhlishahr
# Processing Record 25 of Set 12 | chhukha
# City not found. Skipping...
# Processing Record 26 of Set 12 | wanaka
# Processing Record 27 of Set 12 | uige
# Processing Record 28 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 29 of Set 12 | palmer
# Processing Record 30 of Set 12 | karlstad
# Processing Record 31 of Set 12 | liusha
# Processing Record 32 of Set 12 | gouyave
# Processing Record 33 of Set 12 | lompoc
# Processing Record 34 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 12 | abu dhabi
# Processing Record 36 of Set 12 | nakanojo
# Processing Record 37 of Set 12 | nome
# Processing Record 38 of Set 12 | riosucio
# Processing Record 39 of Set 12 | kakonko
# Processing Record 40 of Set 12 | azangaro
# Processing Record 41 of Set 12 | norman wells
# Processing Record 42 of Set 12 | smithers
# Processing Record 43 of Set 12 | port blair
# Processing Record 44 of Set 12 | manta
# Processing Record 45 of Set 12 | ilebo
# Processing Record 46 of Set 12 | sao joao da barra
# Processing Record 47 of Set 12 | tanete
# Processing Record 48 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 12 | ryotsu
# Processing Record 50 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 1 of Set 13 | kings mountain
# Processing Record 2 of Set 13 | ouesso
# Processing Record 3 of Set 13 | fare
# Processing Record 4 of Set 13 | rio grande
# Processing Record 5 of Set 13 | santa luzia
# Processing Record 6 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 13 | mingoyo
# Processing Record 8 of Set 13 | kalmunai
# Processing Record 9 of Set 13 | san-pedro
# Processing Record 10 of Set 13 | kismayo
# Processing Record 11 of Set 13 | honiara
# Processing Record 12 of Set 13 | jalu
# Processing Record 13 of Set 13 | zyryanka
# Processing Record 14 of Set 13 | tucuman
# Processing Record 15 of Set 13 | manaure
# Processing Record 16 of Set 13 | penzance
# Processing Record 17 of Set 13 | madang
# Processing Record 18 of Set 13 | beira
# Processing Record 19 of Set 13 | kununurra
# Processing Record 20 of Set 13 | cayenne
# Processing Record 21 of Set 13 | pili
# Processing Record 22 of Set 13 | akropong
# Processing Record 23 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 13 | kavaratti
# Processing Record 25 of Set 13 | touros
# Processing Record 26 of Set 13 | emba
# Processing Record 27 of Set 13 | ugoofaaru
# Processing Record 28 of Set 13 | sur
# Processing Record 29 of Set 13 | porto novo
# Processing Record 30 of Set 13 | balykshi
# Processing Record 31 of Set 13 | qarqin
# Processing Record 32 of Set 13 | praia
# Processing Record 33 of Set 13 | marsabit
# Processing Record 34 of Set 13 | yulara
# Processing Record 35 of Set 13 | gizo
# Processing Record 36 of Set 13 | portland
# Processing Record 37 of Set 13 | zhumadian
# Processing Record 38 of Set 13 | gambiran
# Processing Record 39 of Set 13 | palmaner
# Processing Record 40 of Set 13 | mount isa
# Processing Record 41 of Set 13 | antofagasta
# Processing Record 42 of Set 13 | atambua
# Processing Record 43 of Set 13 | slave lake
# Processing Record 44 of Set 13 | salima
# Processing Record 45 of Set 13 | auki
# Processing Record 46 of Set 13 | oyek
# Processing Record 47 of Set 13 | blyth
# Processing Record 48 of Set 13 | teluk nibung
# Processing Record 49 of Set 13 | bueu
# Processing Record 50 of Set 13 | nkowakowa
# Processing Record 1 of Set 14 | longyearbyen
# Processing Record 2 of Set 14 | along
# Processing Record 3 of Set 14 | kavieng
# Processing Record 4 of Set 14 | ixtapa
# Processing Record 5 of Set 14 | bulungu
# Processing Record 6 of Set 14 | erenhot
# Processing Record 7 of Set 14 | gladstone
# Processing Record 8 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 14 | sohag
# Processing Record 10 of Set 14 | kisangani
# Processing Record 11 of Set 14 | cedar city
# Processing Record 12 of Set 14 | husavik
# Processing Record 13 of Set 14 | anzio
# Processing Record 14 of Set 14 | krasnokamensk
# Processing Record 15 of Set 14 | leningradskiy
# Processing Record 16 of Set 14 | soligalich
# Processing Record 17 of Set 14 | punta alta
# Processing Record 18 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 14 | othonoi
# City not found. Skipping...
# Processing Record 20 of Set 14 | jiroft
# City not found. Skipping...
# Processing Record 21 of Set 14 | zambezi
# Processing Record 22 of Set 14 | acobamba
# Processing Record 23 of Set 14 | alice springs
# Processing Record 24 of Set 14 | ponta delgada
# Processing Record 25 of Set 14 | alta floresta
# Processing Record 26 of Set 14 | seguin
# Processing Record 27 of Set 14 | mokhsogollokh
# Processing Record 28 of Set 14 | shaunavon
# Processing Record 29 of Set 14 | metro
# Processing Record 30 of Set 14 | harjavalta
# Processing Record 31 of Set 14 | nivala
# Processing Record 32 of Set 14 | quatre cocos
# Processing Record 33 of Set 14 | gobabis
# Processing Record 34 of Set 14 | margate
# Processing Record 35 of Set 14 | makakilo city
# Processing Record 36 of Set 14 | tabou
# Processing Record 37 of Set 14 | orslev
# Processing Record 38 of Set 14 | santa elena
# Processing Record 39 of Set 14 | fort payne
# Processing Record 40 of Set 14 | honningsvag
# Processing Record 41 of Set 14 | santa isabel
# Processing Record 42 of Set 14 | labuhan
# Processing Record 43 of Set 14 | yeniseysk
# Processing Record 44 of Set 14 | manicore
# Processing Record 45 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 14 | san jose
# Processing Record 47 of Set 14 | mnogovershinnyy
# Processing Record 48 of Set 14 | aitape
# Processing Record 49 of Set 14 | camocim
# Processing Record 50 of Set 14 | college
# Processing Record 1 of Set 15 | siedlce
# Processing Record 2 of Set 15 | urubicha
# Processing Record 3 of Set 15 | smolenka
# Processing Record 4 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 5 of Set 15 | walvis bay
# Processing Record 6 of Set 15 | astana
# Processing Record 7 of Set 15 | stabat
# Processing Record 8 of Set 15 | issaquah
# Processing Record 9 of Set 15 | chifeng
# Processing Record 10 of Set 15 | mizdah
# Processing Record 11 of Set 15 | kimbe
# Processing Record 12 of Set 15 | ardakan
# Processing Record 13 of Set 15 | aswan
# Processing Record 14 of Set 15 | shellbrook
# Processing Record 15 of Set 15 | pimenteiras
# Processing Record 16 of Set 15 | sechura
# Processing Record 17 of Set 15 | inhambane
# Processing Record 18 of Set 15 | scarborough
# Processing Record 19 of Set 15 | southbridge
# Processing Record 20 of Set 15 | skegness
# Processing Record 21 of Set 15 | khani
# Processing Record 22 of Set 15 | olinda
# Processing Record 23 of Set 15 | vestmanna
# Processing Record 24 of Set 15 | kurdzhinovo
# Processing Record 25 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 15 | seoul
# Processing Record 27 of Set 15 | sidi ali
# Processing Record 28 of Set 15 | tiarei
# Processing Record 29 of Set 15 | bandar penggaram
# City not found. Skipping...
# Processing Record 30 of Set 15 | naze
# Processing Record 31 of Set 15 | lokosovo
# Processing Record 32 of Set 15 | bilma
# Processing Record 33 of Set 15 | dakar
# Processing Record 34 of Set 15 | uchiza
# Processing Record 35 of Set 15 | nizhnyaya omka
# Processing Record 36 of Set 15 | podgorenskiy
# Processing Record 37 of Set 15 | itarema
# Processing Record 38 of Set 15 | la asuncion
# Processing Record 39 of Set 15 | shirokiy
# Processing Record 40 of Set 15 | darnah
# Processing Record 41 of Set 15 | hattiesburg
# Processing Record 42 of Set 15 | ila
# Processing Record 43 of Set 15 | miramar
# Processing Record 44 of Set 15 | centralina
# Processing Record 45 of Set 15 | lugovskiy
# City not found. Skipping...
# Processing Record 46 of Set 15 | sisian
# Processing Record 47 of Set 15 | anahuac
# Processing Record 48 of Set 15 | calabozo
# Processing Record 49 of Set 15 | logrono
# Processing Record 50 of Set 15 | wilmington
# Processing Record 1 of Set 16 | makokou
# Processing Record 2 of Set 16 | maiduguri
# Processing Record 3 of Set 16 | urumqi
# Processing Record 4 of Set 16 | oktyabrskoye
# Processing Record 5 of Set 16 | sertanopolis
# Processing Record 6 of Set 16 | venado tuerto
# Processing Record 7 of Set 16 | gilbues
# Processing Record 8 of Set 16 | zhicheng
# Processing Record 9 of Set 16 | shunyi
# Processing Record 10 of Set 16 | riyaq
# City not found. Skipping...
# Processing Record 11 of Set 16 | ozark
# Processing Record 12 of Set 16 | mana
# Processing Record 13 of Set 16 | vestmannaeyjar
# Processing Record 14 of Set 16 | porto nacional
# Processing Record 15 of Set 16 | batagay-alyta
# Processing Record 16 of Set 16 | astara
# Processing Record 17 of Set 16 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 16 | date
# Processing Record 19 of Set 16 | viedma
# Processing Record 20 of Set 16 | darhan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nanortalik      GL  60.1432  -45.2371     39.51        98         100
# 1   Yellowknife      CA  62.4560 -114.3525     73.92        20          20
# 2   East London      ZA -33.0153   27.9116     61.95        61         100
# 3        Pakxan      LA  18.3778  103.6601     80.85        82          84
# 4     Nadapuram      IN  11.7000   75.6667     75.76        90         100
# 5        Bethel      US  41.3712  -73.4140     66.29        38          40
# 6  Beringovskiy      RU  63.0500  179.3167     47.10        83         100
# 7         Sitka      US  57.0531 -135.3300     53.49        82         100
# 8     Mahebourg      MU -20.4081   57.7000     66.25        72          10
# 9  Punta Arenas      CL -53.1500  -70.9167     35.71        80           0
#
#    Wind Speed Current Description
# 0        6.96     overcast clouds
# 1       11.50          few clouds
# 2        6.33     overcast clouds
# 3        2.55       broken clouds
# 4        1.72          light rain
# 5        4.61    scattered clouds
# 6       12.77          light rain
# 7       12.66     overcast clouds
# 8       10.13           clear sky
# 9        6.91           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
